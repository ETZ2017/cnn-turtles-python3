# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../_extracted_dataset/turtle_image_metadata.csv')
# Out:
# /tmp/ipykernel_3411608/2280473728.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../_extracted_dataset/turtle_image_metadata.csv')

# %%
data.tail()
# Out:
#                                             file_location  \
# 115397  duke_turtles/20150809cr7mainnestingbeachslanep...
# 115398  duke_turtles/20150809cr7mainnestingbeachslanep...
# 115399  duke_turtles/20150809cr7mainnestingbeachslanep...
# 115400  duke_turtles/20150809cr7mainnestingbeachslanep...
# 115401  duke_turtles/20150809cr7mainnestingbeachslanep...
#
#                                                  filename location  \
# 115397  20150809cr7mainnestingbeachslanepm_20150809_23...    South
# 115398  20150809cr7mainnestingbeachslanepm_20150809_23...    South
# 115399  20150809cr7mainnestingbeachslanepm_20150809_23...    South
# 115400  20150809cr7mainnestingbeachslanepm_20150809_23...    South
# 115401  20150809cr7mainnestingbeachslanepm_20150809_23...    South
#
#                    datetime     top    left label  model_prob  ImageHeight  \
# 115397  2015:08:09 23:38:49  2470.0   260.0     0    0.158800         3048
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115402 entries, 0 to 115401
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   file_location  115402 non-null  object
#  1   filename       115402 non-null  object
#  2   location       115402 non-null  object
#  3   datetime       115402 non-null  object
#  4   top            115384 non-null  float64
#  5   left           115384 non-null  float64
#  6   label          115384 non-null  object
#  7   model_prob     115384 non-null  float64
#  8   ImageHeight    115402 non-null  int64
#  9   ImageWidth     115402 non-null  int64
#  10  GPSLongitude   115402 non-null  float64
#  11  GPSLatitude    115402 non-null  float64
#  12  GPSAltitude    115402 non-null  float64
#  13  Roll           115402 non-null  float64
#  14  Pitch          115402 non-null  float64
#  15  Yaw            115402 non-null  float64
#  16  FOV            115402 non-null  float64
# ...

# %%
len(data['filename'].unique())
# Out:
# 1059

# %%
data['label'].describe()
# Out:
# count     115384
# unique         5
# top            0
# freq      113223
# Name: label, dtype: object

# %%
data[data['label'] == '1'][0:1].values[0]
# Out:
# array(['duke_turtles_r1/8Aug20158Aug20158RioBeach3KMLanePM20150807cr5surprisebeach3kmlaneimg_20150808_011710_to_20150808_012603',
#        '8Aug20158Aug20158RioBeach3KMLanePM20150807cr5surprisebeach3kmlaneimg_20150808_011847_IMG_6116_NIR.jpg',
#        'surprisebeach', '2015:08:08 01:18:47', 390.0, 1625.0, '1',
#        0.019462, 3048, 4048, -85.71807848, 9.998447336, 92.56927495,
#        2.102468967, 3.18894434, 219.9093628, 73.34058337, 'surprisebeach',
#        -349.0, 1084.0, 0.034053545, -11.88468719, 36.91404274],
#       dtype=object)

# %%
folder_name = data[data['label'] == '0'][6:7].values[0][0]
file_name = data[data['label'] == '0'][6:7].values[0][1]
x = data[data['label'] == '0'][6:7].values[0][4]
y = data[data['label'] == '0'][6:7].values[0][5]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

# Load the image
img = mpimg.imread(f'../{folder_name}/{file_name}') 

# Display the image
plt.imshow(img)
circle = patches.Circle((x,y), 100, edgecolor='r', facecolor='None')  # You can customize edgecolor and facecolor

# Add the circle to the plot
plt.gca().add_patch(circle)

# Show the plot
plt.show()

# %%
folder_name = data[data['label'] == 'Certain Turtle'][6:7].values[0][0]
file_name = data[data['label'] == 'Certain Turtle'][6:7].values[0][1]
x = data[data['label'] == 'Certain Turtle'][6:7].values[0][18]
y = data[data['label'] == 'Certain Turtle'][6:7].values[0][19]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

# Load the image
img = mpimg.imread(f'../{folder_name}/{file_name}') 

# Display the image
plt.imshow(img)
circle = patches.Circle((x,y), 100, edgecolor='r', facecolor='None')  # You can customize edgecolor and facecolor

# Add the circle to the plot
plt.gca().add_patch(circle)

# Show the plot
plt.show()

# %%
folder_name = data[data['label'] == 'Certain Turtle'][7:8].values[0][0]
file_name = data[data['label'] == 'Certain Turtle'][7:8].values[0][1]
x = data[data['label'] == 'Certain Turtle'][7:8].values[0][18]
y = data[data['label'] == 'Certain Turtle'][7:8].values[0][19]

# %%
len(data[data['label'] == 'Certain Turtle'])
# Out:
# 1092

# %%
data[(data[data['label'] == 'Certain Turtle']['filename']) == (data[data['label'] == '3']['filename'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 data[(data[data['label'] == 'Certain Turtle']['filename']) == (data[data['label'] == '3']['filename'])]
#
# File ~/.conda/envs/ai_701/lib/python3.9/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.conda/envs/ai_701/lib/python3.9/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/.conda/envs/ai_701/lib/python3.9/site-packages/pandas/core/series.py:5794, in Series._cmp_method(self, other, op)
# ...

# %%
result = data[data['label'] == 'Certain Turtle'][data['filename'].isin(data[data['label'].isin(['0', '1', '3', '4'])]['filename'].unique())]
len(result)
# Out:
# /tmp/ipykernel_3411608/16525733.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = data[data['label'] == 'Certain Turtle'][data['filename'].isin(data[data['label'].isin(['0', '1', '3', '4'])]['filename'].unique())]
# 1090

# %%
repeated = result[0:1][0:1].values[0][1]
# repeated = result.sample(n=1, random_state=42).values[0][1]

# %%
sample = data[(data['filename'] == repeated) & (data['label'].isin(['Certain Turtle', '0', '1', '3', '4']))].sort_values(by=['label'])
sample
# Out:
#                                          file_location  \
# 543  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 629  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 628  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 627  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 626  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# ..                                                 ...
# 614  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 547  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 656  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 601  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
# 610  duke_turtles_r1/6Aug20156Aug20153RioBeach3KMLa...
#
#                                               filename       location  \
# 543  6Aug20156Aug20153RioBeach3KMLaneAM20150806cr4s...  surprisebeach
# 629  6Aug20156Aug20153RioBeach3KMLaneAM20150806cr4s...  surprisebeach
# 628  6Aug20156Aug20153RioBeach3KMLaneAM20150806cr4s...  surprisebeach
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

# Create a 2x3 grid of subplots (2 rows, 3 columns)
fig, axs = plt.subplots(3, 4, figsize=(20, 12))  # Adjust the figsize as needed

# Flatten the 2D array of subplots into a 1D array
axs = axs.flatten()

for i in range(len(sample[0:12])):

    folder_name = sample[i:i+1].values[0][0]
    file_name = sample[i:i+1].values[0][1]
    
    x = sample[i:i+1].values[0][5]
    y = sample[i:i+1].values[0][4]

    # Load the image
    img = mpimg.imread(f'../{folder_name}/{file_name}') 

    # Display the image
    axs[i].imshow(img)
    circle = patches.Circle((x,y), 200, edgecolor='r', facecolor='None')  # You can customize edgecolor and facecolor

    # Add the circle to the plot
    axs[i].add_patch(circle)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

# Create a 2x3 grid of subplots (2 rows, 3 columns)
fig, axs = plt.subplots(1, 5, figsize=(20, 25))  # Adjust the figsize as needed

# Flatten the 2D array of subplots into a 1D array
axs = axs.flatten()

for i in range(10,15):

    folder_name = data[data['label'] == 'Certain Turtle'][i:i+1].values[0][0]
    file_name = data[data['label'] == 'Certain Turtle'][i:i+1].values[0][1]
    
    x = data[data['label'] == 'Certain Turtle'][i:i+1].values[0][18]
    y = data[data['label'] == 'Certain Turtle'][i:i+1].values[0][19]

    # Load the image
    img = mpimg.imread(f'../{folder_name}/{file_name}') 

    # Display the image
    axs[i % 5].imshow(img)
    circle = patches.Circle((x,y), 100, edgecolor='r', facecolor='None')  # You can customize edgecolor and facecolor

    # Add the circle to the plot
    axs[i % 5].add_patch(circle)

# Show the plot
plt.show()

# %%
folder_name = data[data['label'] == '1'][7:8].values[0][0]
file_name = data[data['label'] == '1'][7:8].values[0][1]
x = data[data['label'] == '1'][7:8].values[0][4]
y = data[data['label'] == '1'][7:8].values[0][5]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

# Load the image
img = mpimg.imread(f'../{folder_name}/{file_name}') 

# Display the image
plt.imshow(img)
circle = patches.Circle((x,y), 100, edgecolor='r', facecolor='None')  # You can customize edgecolor and facecolor

# Add the circle to the plot
plt.gca().add_patch(circle)

# Show the plot
plt.show()

# %%
len(data) - len(data[data['label'].isin(['0','Certain Turtle'])])
# Out:
# 1087
